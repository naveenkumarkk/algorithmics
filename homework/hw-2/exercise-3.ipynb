# %%
import random
import time
import sys

sys.setrecursionlimit(1500)

# Generate a list of random numbers
rnumbers = random.sample(range(1, 10**8), 10**6)
# rnumbers = random.sample(range(1, 10**8), 10**3) # small data for initial test
snumbers = rnumbers.copy()
snumbers.sort()

# Different size integers
small_integers = [5, 12, 23, 1, 45, 9, 2, 100, 37, 0, 50, 3]
large_integers = [
    10**12, 5*10**14, 2*10**16, 1*10**18, 9*10**15, 3*10**13,
    6*10**11, 8*10**10, 4*10**9, 7*10**8
]

floating_numbers = [1.234, 3.1415, 2.718, 9.81, 0.577, 4.669, 6.022, 1.618, 2.685, 5.832]
random_data = [random.randint(1, 1000) for _ in range(100)]

# Sort the list using the quick sort algorithm
def quickSort(arr, low, high):

    if (high <= low) : return

    pivot = arr[high]     # pivot
    i = low
    j = high-1

    while( i <= j ) :
        if arr[i] < pivot:
            i = i+1
        else :
            arr[i], arr[j] = arr[j], arr[i]
            j = j-1
            i = i + 1
    pi = i
    arr[pi], arr[high] = arr[high], arr[pi]

    quickSort(arr, low, pi-1)
    quickSort(arr, pi+1, high)

# Let's compare the two sorting methods
print( "# Built-in 1")
for i in range(3):
  numbers = rnumbers.copy()
  start_time = time.time()
  numbers.sort()
  end_time = time.time()
  print(f"Time to sort {len(numbers)} elements: {end_time - start_time:.2f} seconds")

print( "# Built-in 2")
numbers = rnumbers.copy()
for i in range(3):
  start_time = time.time()
  numbers.sort()
  end_time = time.time()
  print(f"Time to sort {len(numbers)} elements: {end_time - start_time:.2f} seconds")


print( "# Quicksort 1")
for i in range(3):
  numbers = rnumbers.copy()
  start_time = time.time()
  quickSort( numbers, 0, len(numbers)-1 )
  end_time = time.time()
  print(f"Time to sort {len(numbers)} elements: {end_time - start_time:.2f} seconds")
  if numbers == snumbers:
    pass
    # print("OK - Quicksort was correct")
  else:
    print("Error: Quicksort code was wrong")

print( "# Quicksort 2")
numbers = rnumbers.copy()
for i in range(3):
  start_time = time.time()
  quickSort( numbers, 0, len(numbers)-1 )
  end_time = time.time()
  print(f"Time to sort {len(numbers)} elements: {end_time - start_time:.2f} seconds")

print( "# Quicksort 3 : Small Integers")
numbers = small_integers
start_time = time.time()
quickSort( numbers, 0, len(numbers)-1 )
end_time = time.time()
print(f"Time to sort {len(numbers)} elements: {end_time - start_time:.2f} seconds")


print( "# Quicksort 4 : Large Integers")
numbers = large_integers
start_time = time.time()
quickSort( numbers, 0, len(numbers)-1 )
end_time = time.time()
print(f"Time to sort {len(numbers)} elements: {end_time - start_time:.2f} seconds")


print( "# Quicksort 5 : Floating Numbers")
numbers = floating_numbers
start_time = time.time()
quickSort( numbers, 0, len(numbers)-1 )
end_time = time.time()
print(f"Time to sort {len(numbers)} elements: {end_time - start_time:.2f} seconds")


print( "# Quicksort 6: Random Data")
numbers = random_data
start_time = time.time()
quickSort( numbers, 0, len(numbers)-1 )
end_time = time.time()
print(f"Time to sort {len(numbers)} elements: {end_time - start_time:.2f} seconds")
