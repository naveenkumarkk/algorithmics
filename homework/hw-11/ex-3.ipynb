# %% [markdown]
# # Given

# %%
# Sample list of common medicines
medicines = [
    "Acetaminophen", "Ibuprofen", "Aspirin", "Amoxicillin", "Metformin",
    "Lisinopril", "Levothyroxine", "Amlodipine", "Metoprolol", "Omeprazole",
    "Losartan", "Simvastatin", "Atorvastatin", "Albuterol", "Prednisone",
    "Gabapentin", "Hydrochlorothiazide", "Furosemide", "Azithromycin", "Tramadol",
    "Cyclobenzaprine", "Clopidogrel", "Doxycycline", "Citalopram", "Fluoxetine",
    "Sertraline", "Alprazolam", "Escitalopram", "Lorazepam", "Warfarin",
    "Meloxicam", "Sulfasalazine", "Cephalexin", "Venlafaxine", "Tamsulosin",
    "Ondansetron", "Ranitidine", "Hydroxyzine", "Propranolol", "Naproxen",
    "Trazodone", "Clonazepam", "Baclofen", "Amiodarone", "Sitagliptin",
    "Spironolactone", "Allopurinol", "Digoxin", "Vardenafil", "Nitroglycerin",
    "Rivaroxaban", "Saxagliptin", "Ketorolac", "Clindamycin", "Diltiazem",
    "Levofloxacin", "Metronidazole", "Mupirocin", "Bumetanide", "Pantoprazole",
    "Famotidine", "Lamotrigine", "Quetiapine", "Montelukast", "Fluticasone",
    "Methocarbamol", "Meclizine", "Aripiprazole", "Risperidone", "Olanzapine",
    "Topiramate", "Acetazolamide", "Methotrexate", "Alendronate", "Raloxifene",
    "Nystatin", "Fluconazole", "Budesonide", "Valsartan", "Metaxalone",
    "Bisacodyl", "Loperamide", "Bupropion", "Carbamazepine", "Phenobarbital",
    "Sotalol", "Cefuroxime", "Methadone", "Aztreonam", "Amikacin",
    "Ceftriaxone", "Vancomycin", "Penicillin", "Gentamicin", "Meropenem",
    "Ciprofloxacin", "Piperacillin", "Hydralazine", "Ticarcillin", "Clarithromycin",
    "Amantadine", "Oseltamivir", "Valacyclovir", "Acyclovir", "Famciclovir",
    "Tamoxifen", "Letrozole", "Anastrozole", "Exemestane", "Megestrol",
    "Dexamethasone", "Betamethasone", "Hydrocortisone", "Prednisolone", "Triamcinolone",
    "Insulin Glargine", "Insulin Lispro", "Insulin Aspart", "Metformin XR", "Glyburide",
    "Glipizide", "Chlorpropamide", "Tolbutamide", "Pioglitazone", "Rosiglitazone",
    "Canagliflozin", "Dapagliflozin", "Empagliflozin", "Fentanyl", "Morphine",
    "Codeine", "Oxycodone", "Hydromorphone", "Buprenorphine", "Naloxone",
    "Methocarbamol", "Sumatriptan", "Eletriptan", "Zolmitriptan", "Rizatriptan",
    "Mirtazapine", "Venlafaxine XR", "Duloxetine", "Desvenlafaxine", "Vilazodone",
    "Buspirone", "Prazosin", "Seroquel", "Lithium", "Lamotrigine",
    "Phenytoin", "Keppra", "Valproate", "Clozapine", "Aricept",
    "Memantine", "Galantamine", "Rivastigmine", "Haloperidol", "Olanzapine",
    "Invega", "Latuda", "Zyprexa", "Thorazine", "Ritalin",
    "Adderall", "Concerta", "Vyvanse", "Dexmethylphenidate", "Strattera",
    "Modafinil", "Amphetamine", "Lisdexamfetamine", "Dantrolene", "Carisoprodol",
    "Nitrofurantoin", "Metoclopramide", "Domperidone", "Erythromycin", "Trimethoprim",
    "Sulfamethoxazole", "Linezolid", "Telavancin", "Fidaxomicin", "Tigecycline",
    "Eravacycline", "Imipenem", "Colistin", "Clotrimazole", "Terbinafine",
    "Ketoconazole", "Miconazole", "Clobetasol", "Betamethasone", "Desonide",
    "Tacrolimus", "Pimecrolimus", "Dapsone", "Sulfasalazine", "Mesalamine"
]

spellings = [
    'Acetaminophen', 'Acetaminpophen', 'Acetamfnophen', 'Acetaminopten', 'Acetanminophen', 'Acetamnophen',
    'Ibuprofen', 'Ibuprvfen', 'Ibuprofei', 'Ibuprofeg', 'Iburofen', 'Ibprofen',
    'Aspirin', 'Aspivin', 'Aspirij', 'Asvirin', 'Aspiri', 'Aapirin',
    'Amoxicillin', 'Amoxicillsn', 'Amxicillin', 'Amoxqicillin', 'omoxicillin', 'Amoxicilln',
    'Metformin', 'Mtformin', 'Metforfmin', 'Metformiin', 'Metforcin', 'Mewformin',
    'Lisinopril', 'Lisnopril', 'Lsinopril', 'Lidinopril', 'aLisinopril', 'Lisingpril',
    'Levothyroxine', 'Leqothyroxine', 'Levothkyroxine', 'Levothroxine', 'evothyroxine', 'Levothyroxie',
    'Amlodipine', 'Amwodipine', 'Amlodipihe', 'Amlodiine', 'Amgodipine', 'Amodipine',
    'Metoprolol', 'Metprolol', 'Metoproll', 'Metoyrolol', 'etoprolol', 'Metoirolol',
    'Omeprazole', 'Omeqprazole', 'xOmeprazole', 'Oeprazole', 'Omeprazolh', 'rOmeprazole',
    'Losartan', 'Losartapn', 'Lofartan', 'Lousartan', 'Losertan', 'Loartan',
    'Simvastatin', 'Simvastaytin', 'Svmvastatin', 'Sixvastatin', 'Simvasatin', 'Simvatatin',
    'Atorvastatin', 'Atorvasttin', 'Atorvastqtin', 'Atobvastatin', 'Atorastatin', 'Atorvastytin',
    'Albuterol', 'jlbuterol', 'Alsuterol', 'kAlbuterol', 'Albuterpol', 'Albutprol',
    'Prednisone', 'Prednxsone', 'Premnisone', 'Prebdnisone', 'Prednilsone', 'mrednisone',
    'Gabapentin', 'Gabapensin', 'Gabapentio', 'Gabapntin', 'Gabapenfin', 'Gabapmntin',
    'Hydrochlorothiazide', 'Hydrochlorothiazixe', 'Hydrochlorotphiazide', 'Hydrochlobrothiazide', 'Hydrmchlorothiazide', 'Hyrochlorothiazide',
    'Furosemide', 'Furolemide', 'Furosemqde', 'Furousemide', 'Fuosemide', 'Fusosemide',
    'Azithromycin', 'czithromycin', 'Azithwomycin', 'Azithromyocin', 'Aezithromycin', 'nzithromycin',
    'Tramadol', 'Tragadol', 'Tramadpl', 'Tramfdol', 'Tramadoy', 'mTramadol',
    'Cyclobenzaprine', 'Cyclobenzatrine', 'nyclobenzaprine', 'Cyclobenzapurine', 'Cyclobenzapriie', 'Cyclobenzaorine',
    'Clopidogrel', 'Cldpidogrel', 'Cvopidogrel', 'Clopidorel', 'Clpidogrel', 'Clopidkgrel',
    'Doxycycline', 'Doxyctcline', 'Doxycyclie', 'Doxycyrcline', 'Doxycyyline', 'Doxycyclibe',
    'Citalopram', 'bitalopram', 'Citalopramj', 'Citalopramo', 'Citalopra', 'Citalopramu',
    'Fluoxetine', 'Fluoxetiqe', 'Fluoxejtine', 'Fluoxetcne', 'Flutoxetine', 'Feuoxetine',
    'Sertraline', 'kSertraline', 'Srtraline', 'Sertralpne', 'Setraline', 'Sertaline',
    'Alprazolam', 'Alprazllam', 'Alerazolam', 'Alprazoam', 'Alprazolalm', 'Alprasolam',
    'Escitalopram', 'Eskcitalopram', 'Escitalopmram', 'sscitalopram', 'Esgcitalopram', 'Escitaropram',
    'Lorazepam', 'Lobazepam', 'Lorazepai', 'Lorazeppm', 'Lorazpam', 'Lurazepam',
    'Warfarin', 'Warfariz', 'dWarfarin', 'rarfarin', 'Warfarie', 'Warfarinf',
    'Meloxicam', 'Melmoxicam', 'Mmloxicam', 'Meloxipam', 'neloxicam', 'Melyxicam',
    'Sulfasalazine', 'Sulfasalazjne', 'Sulfacalazine', 'Sulftsalazine', 'Sulfasalazkne', 'Sulfasalazipe',
    'Cephalexin', 'Cephlexin', 'Cephalxin', 'Cepahalexin', 'Cephatlexin', 'Cepfalexin',
    'Venlafaxine', 'Venlaafaxine', 'Venlafaxnine', 'Venlfaxine', 'Venlafaxize', 'Venlafaxfine',
    'Tamsulosin', 'Tamsuilosin', 'Tasulosin', 'Tamsulosi', 'Tdmsulosin', 'Tamslosin',
    'Ondansetron', 'Ondasetron', 'Ondagsetron', 'Ondannsetron', 'Ondanesetron', 'Ondansetrn',
    'Ranitidine', 'Rantidine', 'Ranitidime', 'Ranatidine', 'Ranitidide', 'Reanitidine',
    'Hydroxyzine', 'Hydroxyzibne', 'Hydroxyzgne', 'Hydnoxyzine', 'Hydoroxyzine', 'Hydroxyzivne',
    'Propranolol', 'Propranolhl', 'Prlpranolol', 'Propranolool', 'Proprakolol', 'Peopranolol',
    'Naproxen', 'Naprmoxen', 'Naproxenu', 'Naperoxen', 'Naproxem', 'Nagroxen',
    'Trazodone', 'Trawodone', 'razodone', 'Trazodrne', 'Trazodhne', 'Tazodone',
    'Clonazepam', 'Clonazjpam', 'Clonaiepam', 'Clooazepam', 'lonazepam', 'Clonaznepam',
    'Baclofen', 'Bacloxen', 'Bacloen', 'Baclofpn', 'Bacalofen', 'Bwaclofen',
    'Amiodarone', 'Amiogarone', 'Amhodarone', 'Amiodarne', 'Amiodaronle', 'Aiodarone',
    'Sitagliptin', 'Sitagloiptin', 'Sftagliptin', 'witagliptin', 'Sitagiptin', 'Sitagliptgn',
    'Spironolactone', 'Spironolactne', 'Spidonolactone', 'Spirponolactone', 'Spironlactone', 'Spironolactoine',
    'Allopurinol', 'Allkpurinol', 'Allopfrinol', 'Alloyurinol', 'Allopurinoa', 'Alleopurinol',
    'Digoxin', 'Dygoxin', 'Digoxkin', 'iigoxin', 'igoxin', 'Difoxin',
    'Vardenafil', 'Vardnafil', 'Vardenaxil', 'Vaydenafil', 'Vardenafio', 'Vardenafic',
    'Nitroglycerin', 'Nitroglyccerin', 'Nitroglyceri', 'Niroglycerin', 'Nitrwglycerin', 'Nisroglycerin',
    'Rivaroxaban', 'Rivaroqaban', 'Rivaroxabrn', 'hRivaroxaban', 'Ripvaroxaban', 'Rivaroxabanu',
    'Saxagliptin', 'Saxagliptcin', 'Saxagliltin', 'Saxagliptpin', 'Saxagliptxin', 'Saxaagliptin',
    'Ketorolac', 'Ktorolac', 'Ketorolak', 'Ketoeolac', 'Kyetorolac', 'Ketoroac',
    'Clindamycin', 'Clndamycin', 'Ciindamycin', 'Clinamycin', 'Clindhmycin', 'Clindayycin',
    'Diltiazem', 'Diltizazem', 'Dxltiazem', 'Diltuazem', 'Doltiazem', 'Diltiaze',
    'Levofloxacin', 'Levaofloxacin', 'Levofloxain', 'Levoflxacin', 'Levnfloxacin', 'Levojfloxacin',
    'Metronidazole', 'Metroidazole', 'Metmonidazole', 'Metronidazol', 'Metroniwazole', 'detronidazole',
    'Mupirocin', 'Mppirocin', 'Mupirocuin', 'wMupirocin', 'Muirocin', 'fupirocin',
    'Bumetanide', 'Bumenanide', 'Bumetanire', 'Btmetanide', 'Bumetanidce', 'Bumetanids',
    'Pantoprazole', 'Ptntoprazole', 'Pantoprnazole', 'Pantopvazole', 'Pantoprwzole', 'Pantoprazoie',
    'Famotidine', 'Famoticdine', 'Famotidile', 'Fmotidine', 'Famonidine', 'Famotndine',
    'Lamotrigine', 'Lamorigine', 'Lamotrigije', 'Lamutrigine', 'Lamotriine', 'Lamotrbgine',
    'Quetiapine', 'Quetiapinqe', 'Quetiapmne', 'Quetiaxine', 'fuetiapine', 'Quetiapite',
    'Montelukast', 'Motelukast', 'Montelukst', 'Moneelukast', 'Monteluukast', 'Montlukast',
    'Fluticasone', 'Fluticvsone', 'Fluticascne', 'Fluticasoone', 'Flutvicasone', 'Flunticasone',
    'Methocarbamol', 'Methocarbtmol', 'Mehhocarbamol', 'Mjthocarbamol', 'Methocardamol', 'Metjocarbamol',
    'Meclizine', 'Meclizinb', 'Mecliine', 'eclizine', 'Meclizinp', 'Meclizinf',
    'Aripiprazole', 'Arpiprazole', 'Aripiprazoye', 'dripiprazole', 'Aripiprahole', 'Aripiprazfle',
    'Risperidone', 'Risperidony', 'Rispridone', 'isperidone', 'Rispfridone', 'Risperidhne',
    'Olanzapine', 'Olanzapie', 'Olansapine', 'lanzapine', 'Olanzapinv', 'mlanzapine',
    'Topiramate', 'Topiratate', 'Topirfamate', 'Topqiramate', 'opiramate', 'Topirabate',
    'Acetazolamide', 'Aietazolamide', 'Acetazoltmide', 'Acetaolamide', 'Acebazolamide', 'Acetazolaeide',
    'Methotrexate', 'Methotexate', 'Methorexate', 'Methotredate', 'Mvthotrexate', 'Myethotrexate',
    'Alendronate', 'Alenhronate', 'Almendronate', 'Alendronatk', 'Alendronqate', 'Alendronatr',
    'Raloxifene', 'Raloxefene', 'Ralloxifene', 'Raloxifezne', 'Raloxifone', 'Raloxlfene',
    'Nystatin', 'Nystagin', 'Nystatiy', 'Nytatin', 'ystatin', 'Nysctatin',
    'Fluconazole', 'Flucdonazole', 'uluconazole', 'Flucovazole', 'Fluconazle', 'dFluconazole',
    'Budesonide', 'Budesoide', 'Budesonlide', 'udesonide', 'Budesotide', 'Budksonide',
    'Valsartan', 'Valsartap', 'Valoartan', 'Valsrtan', 'Valosartan', 'Vlsartan',
    'Metaxalone', 'zetaxalone', 'Metaxialone', 'Metaxalonf', 'Metaxlalone', 'Mataxalone',
    'Bisacodyl', 'Bisaodyl', 'Bisacody', 'Biscodyl', 'Bsacodyl', 'cisacodyl',
    'Loperamide', 'Loceramide', 'Loheramide', 'Loperamixe', 'Loperamidx', 'Loperalide',
    'Bupropion', 'Buprpion', 'Buqpropion', 'eBupropion', 'Buprocion', 'Buropion',
    'Carbamazepine', 'Caqbamazepine', 'Carbamazepiny', 'Carbamazepinea', 'Carbamazpine', 'Carbamaqepine',
    'Phenobarbital', 'Penobarbital', 'Phenobarbktal', 'Phenobtarbital', 'Phenobarbiyal', 'Phenobarxbital',
    'Sotalol', 'Sotaol', 'Sotalgl', 'gSotalol', 'Sotqalol', 'Sotalof',
    'Cefuroxime', 'Cefuroximl', 'Ceforoxime', 'Cefuroime', 'befuroxime', 'Cefuroximet',
    'Methadone', 'Mqethadone', 'oethadone', 'Methadonu', 'Methadobne', 'Muthadone',
    'Aztreonam', 'Azreonam', 'Aztaeonam', 'Aztreona', 'Aztrenam', 'iztreonam',
    'Amikacin', 'Akmikacin', 'Amiqacin', 'Amkacin', 'Amikbcin', 'Amikain',
    'Ceftriaxone', 'Ceftriaxonh', 'Cehtriaxone', 'Cefpriaxone', 'Cefntriaxone', 'Ceftruaxone',
    'Vancomycin', 'Vancobmycin', 'Vancomycfin', 'Vancobycin', 'Vuncomycin', 'Vancomycij',
    'Penicillin', 'Penicillqn', 'Penicullin', 'jPenicillin', 'Penicqllin', 'Pelicillin',
    'Gentamicin', 'Gntamicin', 'Ggntamicin', 'Genlamicin', 'Gentamiin', 'Gentaicin',
    'Meropenem', 'Meropeneqm', 'Merooenem', 'Mgropenem', 'Merhpenem', 'Meyropenem',
    'Ciprofloxacin', 'gCiprofloxacin', 'Ciproflovacin', 'Cnprofloxacin', 'riprofloxacin', 'Ciprofloxaci',
    'Piperacillin', 'Pipejacillin', 'Pipkracillin', 'Pipjracillin', 'Piperacilli', 'Piperacilliz',
    'Hydralazine', 'Hydralazin', 'gydralazine', 'Hydralazie', 'Hydrallazine', 'Hydraoazine',
    'Ticarcillin', 'Tiyarcillin', 'Ticsarcillin', 'Ticarcwillin', 'Tiarcillin', 'Tcarcillin',
    'Clarithromycin', 'Claripthromycin', 'Cjlarithromycin', 'Clarithrocycin', 'Clarthromycin', 'Clarithromycino',
    'Amantadine', 'Amantxdine', 'Ayantadine', 'Amabntadine', 'Amantadin', 'Anantadine',
    'Oseltamivir', 'Oseltaeivir', 'Oseltmivir', 'Oseltadmivir', 'Oseltamtvir', 'Oseltammivir',
    'Valacyclovir', 'Valacyclovit', 'Valacclovir', 'Valacyclovqr', 'galacyclovir', 'Vakacyclovir',
    'Acyclovir', 'Acaclovir', 'Ayclovir', 'qcyclovir', 'Acyclovi', 'Acyclowvir',
    'Famciclovir', 'Famcicldvir', 'Famciclovr', 'Famciclovxr', 'Famcicloovir', 'Famcicloviri',
    'Tamoxifen', 'Tamoxifien', 'Tamoxifyen', 'Taioxifen', 'Tamoifen', 'Tamcoxifen',
    'Letrozole', 'cLetrozole', 'Ltrozole', 'etrozole', 'Letrozoze', 'Letrozoloe',
    'Anastrozole', 'nastrozole', 'Anastrozolf', 'Anastrooole', 'Aastrozole', 'Anstrozole',
    'Exemestane', 'Exemesmtane', 'Exemestae', 'Exemetstane', 'Exemessane', 'Exevestane',
    'Megestrol', 'Megqstrol', 'Migestrol', 'Merestrol', 'Megstrol', 'Megestrwol',
    'Dexamethasone', 'Dexamethaspne', 'Dexamethasoe', 'Dexamethasne', 'Dexmethasone', 'Dexamethasote',
    'Betamethasone', 'Betramethasone', 'Betameteasone', 'Betamethaone', 'Betabmethasone', 'Betametzasone',
    'Hydrocortisone', 'nydrocortisone', 'gydrocortisone', 'Hydrocbrtisone', 'Hydrocortisonje', 'aydrocortisone',
    'Prednisolone', 'rPrednisolone', 'Prednisoloae', 'Prednbsolone', 'Predniselone', 'Prednnsolone',
    'Triamcinolone', 'Triawmcinolone', 'tTriamcinolone', 'Triamcinolonw', 'zriamcinolone', 'Triamjinolone',
    'Insulin Glargine', 'Insulin Gtlargine', 'Insulin Gargine', 'Insulin Glargink', 'Insulin aGlargine', 'Insulic Glargine',
    'Insulin Lispro', 'Inssulin Lispro', 'Inulin Lispro', 'Insulin Lisfpro', 'Insvulin Lispro', 'Insulfin Lispro',
    'Insulin Aspart', 'Inzulin Aspart', 'Insulin Aspcrt', 'Insulin Aspirt', 'nsulin Aspart', 'Insulin Aspaot',
    'Metformin XR', 'Metfkormin XR', 'Metformcin XR', 'Metaormin XR', 'Metformin pR', 'Melformin XR',
    'Glyburide', 'Glbyburide', 'Glyburidue', 'Glybride', 'Glyburice', 'Gfyburide',
    'Glipizide', 'Glitizide', 'Gliizide', 'Glyipizide', 'Glipizice', 'Glipirzide',
    'Chlorpropamide', 'Chlorpropamgde', 'Chlorpropfmide', 'Chlorpropamid', 'Chlopropamide', 'Chlorprowamide',
    'Tolbutamide', 'Tolbutkmide', 'Tolbutaqide', 'Tolbutamidm', 'Tolbutuamide', 'Tolbutamde',
    'Pioglitazone', 'Pioclitazone', 'Pioelitazone', 'Pioiglitazone', 'Pioglitazonn', 'Piogliazone',
    'Rosiglitazone', 'Roiglitazone', 'Rosiglwtazone', 'Rosigitazone', 'Rosrglitazone', 'Rosiglitayone',
    'Canagliflozin', 'Cbnagliflozin', 'Canagliflozian', 'Canaglifllozin', 'Canaglifloin', 'Canlgliflozin',
    'Dapagliflozin', 'Dqapagliflozin', 'Dapagliflozinb', 'Dapaglifloxin', 'Dapawliflozin', 'Daagliflozin',
    'Empagliflozin', 'Empagliflozir', 'Empagliflolzin', 'Empagpiflozin', 'Empaoliflozin', 'Empsgliflozin',
    'Fentanyl', 'Fentayl', 'uFentanyl', 'Fetanyl', 'Fewtanyl', 'Fentafyl',
    'Morphine', 'Morphie', 'Morhine', 'Motphine', 'Mophine', 'Morphne',
    'Codeine', 'Cbodeine', 'Codeino', 'Cqdeine', 'Cvdeine', 'Codevine',
    'Oxycodone', 'Oxycodonpe', 'ixycodone', 'Oxylodone', 'Oxycodoe', 'Oxzcodone',
    'Hydromorphone', 'Hydromorhone', 'Hydromnrphone', 'rydromorphone', 'Hydromorphoue', 'Hydromorphyone',
    'Buprenorphine', 'Buprenorphinze', 'Bqprenorphine', 'Bulrenorphine', 'Buprenorphink', 'Buprenorphije',
    'Naloxone', 'Naloxonhe', 'Naloxonr', 'Nqloxone', 'Nalyxone', 'Naloxote',
    'Methocarbamol', 'Methocarbaiol', 'ethocarbamol', 'Methocarbamoi', 'Methocarbaxol', 'Methocarbamok',
    'Sumatriptan', 'Sumatrmptan', 'Skmatriptan', 'Sumatriptn', 'Sumapriptan', 'Sumtriptan',
    'Eletriptan', 'Eletrijtan', 'Eletripta', 'Eletviptan', 'Eletqiptan', 'Eletripran',
    'Zolmitriptan', 'Zolmitrkptan', 'Zolmitriptarn', 'gZolmitriptan', 'Zollitriptan', 'Zolmitripan',
    'Rizatriptan', 'Rizatriptfan', 'Rizztriptan', 'Rizairiptan', 'izatriptan', 'Rpzatriptan',
    'Mirtazapine', 'Mirtazvapine', 'Mirtaaapine', 'Mirtavapine', 'Mirtazapin', 'Mirtazupine',
    'Venlafaxine XR', 'Venlafaxin XR', 'Venlafaxine Xh', 'Venlafaxine X', 'Venhafaxine XR', 'Venladaxine XR',
    'Duloxetine', 'Dulhoxetine', 'uloxetine', 'Dulloxetine', 'Duyoxetine', 'Dyloxetine',
    'Desvenlafaxine', 'Desvenlafaxne', 'Desvonlafaxine', 'Desvenlafgxine', 'Desvenlofaxine', 'pesvenlafaxine',
    'Vilazodone', 'eVilazodone', 'Vilazodonee', 'Vilazodonze', 'Vilazorone', 'Vilawodone',
    'Buspirone', 'Bsspirone', 'Bmspirone', 'Buspione', 'Buspiroce', 'Buspironen',
    'Prazosin', 'Pazosin', 'Ppazosin', 'Pradosin', 'Praposin', 'Prazoesin',
    'Seroquel', 'Seroquez', 'Seroqael', 'Seroqhuel', 'Seropquel', 'Sroquel',
    'Lithium', 'Litthium', 'Litmium', 'Litkium', 'Lthium', 'Lihium',
    'Lamotrigine', 'Lcmotrigine', 'Lamotjigine', 'Lamotrigin', 'Lamowrigine', 'Lamotigine',
    'Phenytoin', 'Phenytoim', 'Phenytoinc', 'Phenrtoin', 'Phenytoie', 'henytoin',
    'Keppra', 'Kepra', 'Kepxra', 'Keppa', 'teppra', 'Kepprna',
    'Valproate', 'Valproaae', 'Valproave', 'Vlproate', 'Valproat', 'Valprgate',
    'Clozapine', 'Cgozapine', 'Chozapine', 'Clozpine', 'Closapine', 'Chlozapine',
    'Aricept', 'Aricep', 'Ariceupt', 'Ariept', 'Aicept', 'Ahicept',
    'Memantine', 'Mexantine', 'Mmantine', 'Memantite', 'Memantfine', 'Memantinv',
    'Galantamine', 'Galanwamine', 'nalantamine', 'Galantalmine', 'Galfantamine', 'Galantamie',
    'Rivastigmine', 'Rivlstigmine', 'Rivastgmine', 'Rivastiguine', 'Rivkastigmine', 'Rivastigminj',
    'Haloperidol', 'Hploperidol', 'sHaloperidol', 'Halopezridol', 'Haloeridol', 'Hadoperidol',
    'Olanzapine', 'Olanzapin', 'Olanzapune', 'Olanzapinae', 'Olanfapine', 'Olaneapine',
    'Invega', 'Iivega', 'Inega', 'Invea', 'Inveoa', 'Ivega',
    'Latuda', 'Laduda', 'Latudfa', 'kLatuda', 'Lactuda', 'Latudpa',
    'Zyprexa', 'Zyprmxa', 'Zyprex', 'Zypryxa', 'gyprexa', 'Zyprexy',
    'Thorazine', 'Thorazice', 'Thoraxzine', 'Thurazine', 'Thorazhine', 'Thorazin',
    'Ritalin', 'Riwalin', 'Ritalie', 'sitalin', 'Rstalin', 'italin',
    'Adderall', 'Adderal', 'Adderacll', 'Addeall', 'gdderall', 'Addersall',
    'Concerta', 'Concertxa', 'Concertz', 'oncerta', 'Concerra', 'Concertae',
    'Vyvanse', 'Vyvxnse', 'Vyavnse', 'Vyvanxe', 'Vyvaanse', 'Vyyvanse',
    'Dexmethylphenidate', 'Dlxmethylphenidate', 'Dexmethlyphenidate', 'Dexmethylphenidaye', 'Dextmethylphenidate', 'Dexmethylphenidite',
    'Strattera', 'Strtatera', 'Straterpa', 'Stratters', 'Stratterca', 'Strattero',
    'Modafinil', 'Modaafinil', 'Modaflmil', 'modafinilx', 'Modofinil', 'Modafinirl',
    'Amphetamine', 'Amphetmine', 'Amphatamine', 'Ampheiamine', 'Amphetaminei', 'Amophetamine',
    'Lisdexamfetamine', 'Lixdexamfetamine', 'Lisdexamfetmine', 'Lisdexamfetamin', 'Lisdexmfetamine', 'Lisdexamfetaminee',
    'Dantrolene', 'Dantrolere', 'Dantrolend', 'Damntrolene', 'Damtrolene', 'Dantrolne',
    'Carisoprodol', 'Carisporodol', 'Carispodrol', 'Carisoprodal', 'Carosoprodol', 'Caisoprodol',
    'Nitrofurantoin', 'Nitrofuranoin', 'Nitrofurantoina', 'Nitrofuranton', 'Nitrofuranoin', 'Nitrofurantoinb',
    'Metoclopramide', 'Metclopramide', 'Metocloprwmide', 'Metocolopramide', 'Metoclopramidr', 'Metoclopraide',
    'Domperidone', 'Dompridone', 'Domperiione', 'Domoperidone', 'Domperdone', 'Dompridone',
    'Erythromycin', 'Erythromyicn', 'Erythronycin', 'Erythtromycin', 'Eryhthromycin', 'Erythromyocin',
    'Trimethoprim', 'Trimethoprm', 'Trimethoprime', 'Trimethopridm', 'Trimithoprim', 'Trimetoprim',
    'Sulfamethoxazole', 'Sulfamethaxole', 'Sulfaethoxazole', 'Sulfamethoazole', 'Sulfamethxoazole', 'Sulfamethoxazol',
    'Linezolid', 'Linezoild', 'Linezold', 'Linezopid', 'Linezolidc', 'Linezolid',
    'Telavancin', 'Telavacncin', 'Telavanncin', 'Telavacnin', 'Telavanein', 'Telqvancin',
    'Fidaxomicin', 'Fidaxomicinr', 'Fidaxmicin', 'Fidaxomcin', 'Fidxomicin', 'Fixdaxomicin',
    'Tigecycline', 'Tigcyclin', 'Tigecycin', 'Tigcyclinw', 'Tiecycline', 'Tigexcline',
    'Eravacycline', 'Eravayline', 'Eravacylcline', 'Eravacycloine', 'Eravacyclire', 'Eravacyclne',
    'Imipenem', 'Imiptnem', 'Imipenemk', 'Impenem', 'Imimpenem', 'Impimenem',
    'Colistin', 'Clistn', 'Colostin', 'Colistinb', 'Colistinm', 'Coistin',
    'Clotrimazole', 'Clorimazole', 'Cotrimazole', 'Clotrimazoe', 'Clotrimaole', 'Clotrmazole',
    'Terbinafine', 'Terbinafinew', 'Terbinafin', 'Terbfinafine', 'Terbinfine', 'Terbnainfine',
    'Ketoconazole', 'Ketoconaeole', 'Ketoconazok', 'Ketocnazole', 'Ketoconaole', 'Krtoconazole',
    'Miconazole', 'Miconaeole', 'Miconazolle', 'Micanazole', 'Miconazle', 'Mocazonazole',
    'Clobetasol', 'Clotetasol', 'Clobetazol', 'Clobetaso', 'Clobrtasol', 'Clobetassol',
    'Betamethasone', 'Betemethasone', 'Betamethasonee', 'Betamathasone', 'Betamethasonn', 'Betamethasxne',
    'Desonide', 'Desonede', 'Desonode', 'Desonid', 'Desonaide', 'Desonside',
    'Tacrolimus', 'Tacrilmus', 'Tacrolimuse', 'Tacrolimusb', 'Tacrolumis', 'Tacorlimus',
    'Pimecrolimus', 'Pimcrolimus', 'Pimocrolimus', 'Pimercrolimus', 'Primocrolimus', 'Pimecrolimusl',
    'Dapsone', 'Dapsine', 'Dapson', 'Daspone', 'Dopsone', 'Dapskone',
    'Sulfasalazine', 'Sulfasalazine', 'Sulfasalaxine', 'Sulfasalazne', 'Sulfsalazine', 'Sulfqasalazine',
    'Mesalamine', 'Mesalamne', 'Mesalamive', 'Mesalamin', 'Mesalamne', 'Mesolamine'
]

# Writing the medicines list to a text file
file_path = "./medicine_list.txt"
with open(file_path, "w") as file:
    for medicine in medicines:
        file.write(medicine + "\n")

# Writing the spellings list to a text file
file_path = "./spellings_list.txt"
with open(file_path, "w") as file:
    for medicine in spellings:
        file.write(medicine + "\n")

# %%
from difflib import SequenceMatcher
import numpy as np


# Function to calculate edit distance using SequenceMatcher
def edit_distance(str1, str2):
    return 1 - SequenceMatcher(None, str1, str2).ratio()

# Finding the closest 7 names in spellings for each medicine
def find_closest_spellings(medicines, spellings, top_n=7):
    closest_spellings = {}
    for medicine in medicines:
        # Calculate edit distance for each spelling against the current medicine
        distances = [(spelling, edit_distance(medicine, spelling)) for spelling in spellings]
        # Sort by distance and get the top N closest spellings
        distances.sort(key=lambda x: x[1])
        closest_spellings[medicine] = [spelling for spelling, _ in distances[:top_n]]
    return closest_spellings


def calculate_edit_distance_dp(str1, str2):
    len1, len2 = len(str1), len(str2)
    dp = np.zeros((len1 + 1, len2 + 1), dtype=int)

    # Initialize DP table
    for i in range(len1 + 1):
        dp[i][0] = i
    for j in range(len2 + 1):
        dp[0][j] = j

    # Fill the DP table with combined minimize step
    for i in range(1, len1 + 1):
        for j in range(1, len2 + 1):
            cost = 0 if str1[i - 1] == str2[j - 1] else 1
            dp[i][j] = min(dp[i - 1][j] + 1,         # Deletion
                           dp[i][j - 1] + 1,         # Insertion
                           dp[i - 1][j - 1] + cost)  # Substitution (or match if cost is 0)

    return dp[len1][len2]



# Sample usage with the lists medicines and misspelled_medicines
closest_spellings = find_closest_spellings(medicines, spellings)

# Displaying a sample of the result to the user
sample_result = {k: closest_spellings[k] for k in list(closest_spellings.keys())[:5]}

# Applying the function and printing results
results = []
for word, matches in sample_result.items():
    for match in matches:
        distance = calculate_edit_distance_dp(word, match)
        results.append((word, match, distance))

# Displaying the result as requested
results
# Out:
# [('Acetaminophen', 'Acetaminophen', 0),
#  ('Acetaminophen', 'Acetaminpophen', 1),
#  ('Acetaminophen', 'Acetanminophen', 1),
#  ('Acetaminophen', 'Acetamnophen', 1),
#  ('Acetaminophen', 'Acetamfnophen', 1),
#  ('Acetaminophen', 'Acetaminopten', 1),
#  ('Acetaminophen', 'Amphetamine', 7),
#  ('Ibuprofen', 'Ibuprofen', 0),
#  ('Ibuprofen', 'Iburofen', 1),
#  ('Ibuprofen', 'Ibprofen', 1),
#  ('Ibuprofen', 'Ibuprvfen', 1),
#  ('Ibuprofen', 'Ibuprofei', 1),
#  ('Ibuprofen', 'Ibuprofeg', 1),
#  ('Ibuprofen', 'Buspironen', 5),
#  ('Aspirin', 'Aspirin', 0),
#  ('Aspirin', 'Aspiri', 1),
#  ('Aspirin', 'Aspivin', 1),
#  ('Aspirin', 'Aspirij', 1),
#  ('Aspirin', 'Asvirin', 1),
#  ('Aspirin', 'Aapirin', 1),
#  ('Aspirin', 'Mupirocin', 4),
#  ('Amoxicillin', 'Amoxicillin', 0),
#  ('Amoxicillin', 'Amoxqicillin', 1),
#  ('Amoxicillin', 'Amxicillin', 1),
#  ('Amoxicillin', 'Amoxicilln', 1),
#  ('Amoxicillin', 'Amoxicillsn', 1),
#  ('Amoxicillin', 'omoxicillin', 1),
# ...

# %% [markdown]
# # EX3

# %%
from difflib import SequenceMatcher
import numpy as np
from collections import defaultdict

# Function to calculate edit distance using SequenceMatcher
def edit_distance(str1, str2):
    return 1 - SequenceMatcher(None, str1, str2).ratio()

# Modified edit distance function with custom costs
def calculate_edit_distance_dp(str1, str2, del_cost=1, ins_cost=1, sub_cost=1, trans_cost=2):
    len1, len2 = len(str1), len(str2)
    dp = np.zeros((len1 + 1, len2 + 1), dtype=int)

    # Initialize DP table
    for i in range(len1 + 1):
        dp[i][0] = i * del_cost
    for j in range(len2 + 1):
        dp[0][j] = j * ins_cost

    # Fill the DP table
    for i in range(1, len1 + 1):
        for j in range(1, len2 + 1):
            cost = 0 if str1[i - 1] == str2[j - 1] else sub_cost
            dp[i][j] = min(dp[i - 1][j] + del_cost,         # Deletion
                           dp[i][j - 1] + ins_cost,         # Insertion
                           dp[i - 1][j - 1] + cost)  # Substitution (or match)

            # Transposition check
            if i > 1 and j > 1 and str1[i - 1] == str2[j - 2] and str1[i - 2] == str2[j - 1]:
                dp[i][j] = min(dp[i][j], dp[i - 2][j - 2] + trans_cost)
    return dp[len1][len2]


# Function to calculate edit distance using SequenceMatcher
def edit_distance(str1, str2):
    return 1 - SequenceMatcher(None, str1, str2).ratio()

# Finding the closest 7 names in spellings for each medicine
def find_closest_spellings(medicines, spellings, top_n=7):
    closest_spellings = {}
    for medicine in medicines:
        # Calculate edit distance for each spelling against the current medicine
        distances = [(spelling, edit_distance(medicine, spelling)) for spelling in spellings]
        # Sort by distance and get the top N closest spellings
        distances.sort(key=lambda x: x[1])
        closest_spellings[medicine] = [spelling for spelling, _ in distances[:top_n]]
    return closest_spellings



closest_spellings = find_closest_spellings(medicines, spellings)

sample_result = {k: closest_spellings[k] for k in list(closest_spellings.keys())[:5]}

# Applying the function and printing results
results = []
for word, matches in sample_result.items():
    for match in matches:
        distance = calculate_edit_distance_dp(word, match)
        results.append((word, match, distance))


# Analyze single character changes
char_changes = defaultdict(int)
for word, match, distance in results:
    if distance == 1:
      for i in range(min(len(word), len(match))):
        if word[i] != match[i]:
            char_changes[(word[i], match[i])] += 1

print("Single character changes:")
for (original, changed), count in char_changes.items():
    print(f"'{original}' changed to '{changed}' : {count} times")


# Analyze transpositions
transpositions = 0
for word, match, _ in results:
  if len(word) == len(match) and len(word) > 1:
      for i in range(len(word) - 1):
        if word[i:i+2] == match[i+1:i+3][::-1]:
            transpositions +=1
            print(f"Transposition detected: {word} -> {match}")

print(f"Total transpositions detected: {transpositions}")
# Out:
# Single character changes:
# 'o' changed to 'p' : 2 times
# 'p' changed to 'o' : 2 times
# 'h' changed to 'p' : 2 times
# 'e' changed to 'h' : 2 times
# 'n' changed to 'e' : 2 times
# 'm' changed to 'n' : 1 times
# 'i' changed to 'm' : 2 times
# 'n' changed to 'i' : 5 times
# 'o' changed to 'n' : 1 times
# 'i' changed to 'n' : 4 times
# 'n' changed to 'o' : 1 times
# 'p' changed to 'h' : 1 times
# 'h' changed to 'e' : 1 times
# 'e' changed to 'n' : 3 times
# 'i' changed to 'f' : 1 times
# 'h' changed to 't' : 1 times
# 'p' changed to 'r' : 2 times
# 'r' changed to 'o' : 2 times
# 'o' changed to 'f' : 2 times
# 'f' changed to 'e' : 2 times
# 'u' changed to 'p' : 1 times
# 'o' changed to 'v' : 1 times
# 'n' changed to 'g' : 1 times
# 'r' changed to 'v' : 1 times
# 'n' changed to 'j' : 1 times
# 'p' changed to 'v' : 1 times
# 's' changed to 'a' : 1 times
# 'i' changed to 'q' : 1 times
# 'c' changed to 'i' : 2 times
# 'i' changed to 'c' : 2 times
# 'l' changed to 'i' : 2 times
# ...
